# %%
import pandas as pd
total_data=pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/linear-regression-project-tutorial/main/medical_insurance_cost.csv")

# %%
total_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
total_data.shape
# Out:
# (1338, 7)

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
total_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

fig, axis = plt.subplots(1, 3, figsize = (12, 6))

# Crear un histograma múltiple
sns.histplot(ax = axis[0], data = total_data, x = "sex").set(ylabel = None)
sns.histplot(ax = axis[1], data = total_data, x = "smoker").set(ylabel = None)
sns.histplot(ax = axis[2], data = total_data, x = "region")



# sns.histplot(ax = axis[0,0]).set_xticklabels(sns.histplot(ax = axis[0,0]).get_xticklabels(), rotation=45, ha='right')
# sns.histplot(ax = axis[0,2]).set_xticklabels(sns.histplot(ax = axis[0,2]).get_xticklabels(), rotation=45, ha='right')

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
fig, axis = plt.subplots(4, 2, figsize = (10, 11))

# Crear una figura múltiple con histogramas y diagramas de caja
sns.histplot(ax = axis[0, 0], data = total_data, x = "age").set(xlabel = None)
sns.boxplot(ax = axis[1, 0], data = total_data, x = "age")
sns.histplot(ax = axis[0, 1], data = total_data, x = "bmi").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 1], data = total_data, x = "bmi")
sns.histplot(ax = axis[2, 0], data = total_data, x = "children").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 0], data = total_data, x = "children")
sns.histplot(ax = axis[2, 1], data = total_data, x = "charges").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 1], data = total_data, x = "charges")

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
female_df=total_data[total_data['sex']=='female']
male_df=total_data[total_data['sex']=='male']

# %%
fig, axis = plt.subplots(2, 2, figsize = (10, 11))

# Crear una figura múltiple con histogramas y diagramas de caja
sns.histplot(ax = axis[0, 0], data = female_df, x = "charges").set(xlabel = 'Female charges')
sns.boxplot(ax = axis[1, 0], data = female_df, x = "charges")
sns.histplot(ax = axis[0, 1], data = male_df, x = "charges").set(xlabel= 'Male charges')
sns.boxplot(ax = axis[1, 1], data = male_df, x = "charges")


# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
smoker_df=total_data[total_data['smoker']=='yes']
non_smoker_df=total_data[total_data['smoker']=='no']

# %%
non_smoker_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# ...   ...     ...     ...       ...    ...        ...          ...
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
#
# [1064 rows x 7 columns]

# %%
fig, axis = plt.subplots(2, 2, figsize = (10, 11))

# Crear una figura múltiple con histogramas y diagramas de caja
sns.histplot(ax = axis[0, 0], data = smoker_df, x = "charges").set(xlabel = 'Smoker charges', ylim=(0,160), xlim=(0,70000))
sns.boxplot(ax = axis[1, 0], data = smoker_df, x = "charges")
sns.histplot(ax = axis[0, 1], data = non_smoker_df, x = "charges").set(xlabel= 'Non smoker charges', xlim=(0,70000))
sns.boxplot(ax = axis[1, 1], data = non_smoker_df, x = "charges")

#plt.ylim(0, 160)

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
southeast_df=total_data[total_data['region']=='southeast']
southwest_df=total_data[total_data['region']=='southwest']
northwest_df=total_data[total_data['region']=='northwest']
northeast_df=total_data[total_data['region']=='northeast']

# %%
fig, axis = plt.subplots(2, 2, figsize = (10, 11))

# Crear una figura múltiple con histogramas y diagramas de caja
sns.histplot(ax = axis[0, 0], data = southeast_df, x = "charges").set(xlabel = 'southeast charges')
sns.boxplot(ax = axis[1, 0], data = southeast_df, x = "charges")
sns.histplot(ax = axis[0, 1], data = southwest_df, x = "charges").set(xlabel= 'southwest charges')
sns.boxplot(ax = axis[1, 1], data = southwest_df, x = "charges")

#plt.ylim(0, 160)

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
fig, axis = plt.subplots(2, 2, figsize = (10, 11))

# Crear una figura múltiple con histogramas y diagramas de caja
sns.histplot(ax = axis[0, 0], data = northwest_df, x = "charges").set(xlabel = 'northwest charges')
sns.boxplot(ax = axis[1, 0], data = northwest_df, x = "charges")
sns.histplot(ax = axis[0, 1], data = northeast_df, x = "charges").set(xlabel= 'northeast charges')
sns.boxplot(ax = axis[1, 1], data = northeast_df, x = "charges")

#plt.ylim(0, 160)

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %%
print("Mean charges in southeast =",southeast_df['charges'].mean())
print("Mean charges in southwest =",southwest_df['charges'].mean())
print("Mean charges in northwest =",northwest_df['charges'].mean())
print("Mean charges in northeast =",northeast_df['charges'].mean())
# Out:
# Mean charges in southeast = 14735.411437609895
# Mean charges in southwest = 12346.93737729231
# Mean charges in northwest = 12417.575373969228
# Mean charges in northeast = 13406.3845163858

# %% [markdown]
# Podemos apreciar que no hay una diferencia sustancial en las cargas entre una región y otra

# %%
fig, axis = plt.subplots(2, 2, figsize = (10, 7))

# Crear un diagrama de dispersión múltiple
sns.regplot(ax = axis[0, 0], data = total_data, x = "age", y = "charges")
sns.heatmap(total_data[["charges", "age"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)
sns.regplot(ax = axis[0, 1], data = total_data, x = "bmi", y = "charges").set(ylabel=None)
sns.heatmap(total_data[["charges", "bmi"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %% [markdown]
# Podemos apreciar una correlación positiva entre cargas-bmi y cargas-edad

# %%
sns.regplot( data = total_data, x = "children", y = "charges")
sns.heatmap(total_data[["charges", "children"]].corr(), annot = True, fmt = ".2f",  cbar = False)
# Out:
# <AxesSubplot:>

# %%
fig, axis = plt.subplots(2, figsize = (10, 7))

# Crear un diagrama de dispersión múltiple
sns.regplot(ax = axis[0], data = total_data, x = "children", y = "charges")
sns.heatmap(total_data[["charges", "children"]].corr(), annot = True, fmt = ".2f", ax = axis[1], cbar = False)

# Ajustar el layout
plt.tight_layout()

# Mostrar el plot
plt.show()

# %% [markdown]
# Podemos observar que apenas hay correlación entre el número de niños y las cargas

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
total_data["sex"] = pd.factorize(total_data["sex"])[0]
total_data["smoker"] = pd.factorize(total_data["smoker"])[0]
total_data["region"] = pd.factorize(total_data["region"])[0]

# %%
fig, axis = plt.subplots(figsize = (12, 6))

sns.heatmap(total_data[["sex", "smoker", "region","charges"]].corr(), annot = True, fmt = ".2f")

plt.tight_layout()

plt.show()

# %% [markdown]
# Se puede ver una clara correlación negativa entre las cargas y ser fumador. No hay relación entre las cargas y el resto de variables.

# %% [markdown]
# No fumadores lo ha factorizado como 1 y fumadores como 0, luego cuanto menor es el número (0), más altas son las cargas.

# %%
total_data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.795217
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     1.000000
# 50%      39.000000     1.000000    30.400000     1.000000     1.000000
# 75%      51.000000     1.000000    34.693750     2.000000     1.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.484305  13270.422265
# std       1.104885  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       1.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %%
cols=[str(i) for i in total_data.columns] 
cols
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
fig, axis = plt.subplots(figsize = (12, 6))

sns.heatmap(total_data[cols].corr(), annot = True, fmt = ".2f")

plt.tight_layout()

plt.show()

# %% [markdown]
# Las relaciones más claras que podemos apreciar con las cargas son con el bmi y la edad, además de ser fumador: También se puede ver como la prsencia de niños no se relaciona con ninguna otra variable.

# %%
fig, axis = plt.subplots(2, 2, figsize = (15, 10))

sns.boxplot(ax = axis[0, 0], data = total_data, y = "age")
sns.boxplot(ax = axis[0, 1], data = total_data, y = "bmi")
sns.boxplot(ax = axis[1, 0], data = total_data, y = "children")
sns.boxplot(ax = axis[1, 1], data = total_data, y = "charges")


plt.tight_layout()

plt.show()

# %%
from sklearn.model_selection import train_test_split

num_variables = [str(i)  for i in total_data.columns]

# We divide the dataset into training and test samples
X = total_data.drop("charges", axis = 1)#[num_variables]
y = total_data["charges"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 14)

X_train.to_csv("X_train.csv", index=False)
# with open("X_train.csv", "w") as f:
#     f.write(y_train)
X_test.to_csv("X_test.csv", index=False)
# with open("X_test.csv", "w") as f:
#     f.write(y_test)

# %%
y_test.to_csv("y_test.csv", index=False)
y_train.to_csv("y_train.csv", index=False)

# %%
from sklearn.preprocessing import MinMaxScaler
# from pickle import dump

num_variables = [str(i) for i in X_train]

scaler = MinMaxScaler()
scaler.fit(X_train)

X_train_scal = scaler.transform(X_train)
X_train_scal = pd.DataFrame(X_train_scal, index = X_train.index, columns = num_variables)

X_test_scal = scaler.transform(X_test)
X_test_scal = pd.DataFrame(X_test_scal, index = X_test.index, columns = num_variables)

X_train_scal.to_csv("X_train_scal.csv", index=False)
X_test_scal.to_csv("X_test_scal.csv", index=False)
#dump(scaler, open("/workspaces/machine-learning-content/assets/norm_scaler.pk", "wb"))

X_test_scal
# Out:
#            age  sex       bmi  children  smoker    region
# 1038  0.086957  1.0  0.347592       0.0     1.0  1.000000
# 103   0.934783  0.0  0.375572       0.6     0.0  0.333333
# 561   0.782609  0.0  0.449825       0.0     1.0  1.000000
# 1295  0.043478  1.0  0.162497       0.2     1.0  0.000000
# 1243  0.217391  0.0  0.461394       0.0     1.0  0.333333
# ...        ...  ...       ...       ...     ...       ...
# 193   0.826087  0.0  0.286252       0.2     1.0  0.666667
# 736   0.413043  0.0  0.603444       0.0     0.0  0.333333
# 264   0.760870  0.0  0.594566       0.6     1.0  0.333333
# 44    0.434783  1.0  0.567393       0.2     1.0  1.000000
# 1115  0.804348  1.0  0.449556       0.2     1.0  0.333333
#
# [268 rows x 6 columns]

# %%
X_train_scal
# Out:
#            age  sex       bmi  children  smoker    region
# 662   0.304348  0.0  0.419155       0.2     1.0  1.000000
# 189   0.239130  0.0  0.434490       0.4     1.0  0.666667
# 855   0.043478  0.0  0.366963       0.0     1.0  0.000000
# 275   0.630435  0.0  0.286252       0.4     1.0  1.000000
# 1090  0.630435  1.0  0.544256       0.0     0.0  0.333333
# ...        ...  ...       ...       ...     ...       ...
# 746   0.347826  1.0  0.297014       0.4     1.0  0.000000
# 327   0.586957  1.0  0.552058       0.4     0.0  0.666667
# 406   0.326087  0.0  0.224644       0.0     1.0  0.333333
# 1292  0.065217  1.0  0.195050       0.0     1.0  0.333333
# 619   0.804348  0.0  0.568738       0.0     1.0  0.000000
#
# [1070 rows x 6 columns]
